# %%
import pandas as pd
import os
import numpy as np
from scipy.io import arff

# %%
# check if a folder (directory) exists

fill_dirc = './NATOPS'

if os.path.exists(fill_dirc):
    print(f"The folder at '{fill_dirc}' exists.")
else:
    print(f"The folder at '{fill_dirc}' does not exist.")
# Out:
# The folder at './NATOPS' exists.

# %%
file_list_test = [f for f in os.listdir(fill_dirc) if (f.startswith('NATOPSDimension') and 'TEST' in f)]
file_list_test.sort()

# %%
file_list_test
# Out:
# ['NATOPSDimension10_TEST.arff',
#  'NATOPSDimension11_TEST.arff',
#  'NATOPSDimension12_TEST.arff',
#  'NATOPSDimension13_TEST.arff',
#  'NATOPSDimension14_TEST.arff',
#  'NATOPSDimension15_TEST.arff',
#  'NATOPSDimension16_TEST.arff',
#  'NATOPSDimension17_TEST.arff',
#  'NATOPSDimension18_TEST.arff',
#  'NATOPSDimension19_TEST.arff',
#  'NATOPSDimension1_TEST.arff',
#  'NATOPSDimension20_TEST.arff',
#  'NATOPSDimension21_TEST.arff',
#  'NATOPSDimension22_TEST.arff',
#  'NATOPSDimension23_TEST.arff',
#  'NATOPSDimension24_TEST.arff',
#  'NATOPSDimension2_TEST.arff',
#  'NATOPSDimension3_TEST.arff',
#  'NATOPSDimension4_TEST.arff',
#  'NATOPSDimension5_TEST.arff',
#  'NATOPSDimension6_TEST.arff',
#  'NATOPSDimension7_TEST.arff',
#  'NATOPSDimension8_TEST.arff',
#  'NATOPSDimension9_TEST.arff']

# %%
file_list_train = [f for f in os.listdir(fill_dirc) if (f.startswith('NATOPSDimension') and 'TRAIN' in f)]
file_list_train.sort()

# %%
file_list_train
# Out:
# ['NATOPSDimension10_TRAIN.arff',
#  'NATOPSDimension11_TRAIN.arff',
#  'NATOPSDimension12_TRAIN.arff',
#  'NATOPSDimension13_TRAIN.arff',
#  'NATOPSDimension14_TRAIN.arff',
#  'NATOPSDimension15_TRAIN.arff',
#  'NATOPSDimension16_TRAIN.arff',
#  'NATOPSDimension17_TRAIN.arff',
#  'NATOPSDimension18_TRAIN.arff',
#  'NATOPSDimension19_TRAIN.arff',
#  'NATOPSDimension1_TRAIN.arff',
#  'NATOPSDimension20_TRAIN.arff',
#  'NATOPSDimension21_TRAIN.arff',
#  'NATOPSDimension22_TRAIN.arff',
#  'NATOPSDimension23_TRAIN.arff',
#  'NATOPSDimension24_TRAIN.arff',
#  'NATOPSDimension2_TRAIN.arff',
#  'NATOPSDimension3_TRAIN.arff',
#  'NATOPSDimension4_TRAIN.arff',
#  'NATOPSDimension5_TRAIN.arff',
#  'NATOPSDimension6_TRAIN.arff',
#  'NATOPSDimension7_TRAIN.arff',
#  'NATOPSDimension8_TRAIN.arff',
#  'NATOPSDimension9_TRAIN.arff']

# %% [markdown]
# # training dataset

# %%
datasets_train = []

# %%
# Read and convert each ARFF file to DataFrame
for file_name in file_list_train:
    file_path = os.path.join(fill_dirc, file_name)
    data, meta = arff.loadarff(file_path)

    df = pd.DataFrame(data)

    datasets_train.append(df)
    
for df in datasets_train:
  
    df.insert(0, 'sample_id', range(1, 181))

    # for training data, data_type = 0
    df.insert(1, 'data_type', 0)

# %%
datasets_train[0]
# Out:
#      sample_id  data_type  channel_9_0  channel_9_1  channel_9_2  channel_9_3  \
# 0            1          0     0.599967     0.597535     0.597007     0.599099
# 1            2          0     0.622368     0.622228     0.622004     0.621909
# 2            3          0     0.588525     0.588389     0.588164     0.588034
# 3            4          0     0.576847     0.576713     0.575015     0.575267
# 4            5          0     0.717469     0.722515     0.725107     0.726653
# ..         ...        ...          ...          ...          ...          ...
# 175        176          0     0.449758     0.450994     0.452902     0.453383
# 176        177          0     0.493027     0.493617     0.512562     0.520631
# 177        178          0     0.595485     0.596915     0.596601     0.595914
# 178        179          0     0.490263     0.493245     0.491447     0.498680
# 179        180          0     0.617926     0.617853     0.617932     0.617893
#
#      channel_9_4  channel_9_5  channel_9_6  channel_9_7  ...  channel_9_42  \
# 0       0.606181     0.620752     0.630438     0.631059  ...      0.481070
# 1       0.621940     0.622165     0.622169     0.622187  ...      0.633561
# 2       0.587961     0.587895     0.591413     0.605781  ...      0.628961
# 3       0.572163     0.555767     0.555370     0.603450  ...      0.864772
# 4       0.709988     0.712092     0.718585     0.732054  ...      0.704474
# ..           ...          ...          ...          ...  ...           ...
# 175     0.450813     0.451069     0.452570     0.451893  ...      0.779229
# 176     0.542981     0.620562     0.669893     0.690886  ...      0.505139
# 177     0.596636     0.595807     0.596126     0.595526  ...      0.770619
# 178     0.504925     0.512147     0.521547     0.523235  ...      0.609115
# 179     0.615398     0.617709     0.688873     0.792850  ...      1.121576
#
#      channel_9_43  channel_9_44  channel_9_45  channel_9_46  channel_9_47  \
# 0        0.448322      0.446156      0.463632      0.472489      0.478672
# 1        0.625020      0.621246      0.620114      0.622860      0.626455
# 2        0.628775      0.629428      0.629564      0.630303      0.630190
# 3        0.703532      0.610663      0.492510      0.469339      0.450966
# 4        0.702400      0.697387      0.709375      0.726443      0.726608
# ..            ...           ...           ...           ...           ...
# 175      0.758020      0.698059      0.654596      0.575610      0.474669
# 176      0.500421      0.477549      0.476964      0.459504      0.460537
# 177      0.703594      0.657176      0.624122      0.617318      0.618746
# 178      0.554548      0.502891      0.462087      0.445913      0.457320
# 179      0.995196      0.897630      0.798350      0.732601      0.667282
#
#      channel_9_48  channel_9_49  channel_9_50  classAttribute
# 0        0.483420      0.524973      0.529075          b'4.0'
# 1        0.629063      0.629925      0.630044          b'3.0'
# 2        0.630377      0.629650      0.629911          b'3.0'
# 3        0.445467      0.468875      0.473101          b'4.0'
# 4        0.733353      0.735488      0.729625          b'3.0'
# ..            ...           ...           ...             ...
# 175      0.384671      0.355565      0.351775          b'4.0'
# 176      0.445883      0.448401      0.450815          b'5.0'
# 177      0.627077      0.629380      0.631474          b'1.0'
# 178      0.481055      0.504416      0.497571          b'4.0'
# 179      0.579626      0.565539      0.566283          b'4.0'
#
# [180 rows x 54 columns]

# %%
expanded_columns_train = []
column_name = []

for df in datasets_train:
    selected_data = df.iloc[:, 2:53]
    
    column_name.append(df.columns[2].split('_')[1])

    expanded_data = []
    
    for _, row in selected_data.iterrows():
        
        expanded_data.extend(row.tolist())
        
    
    expanded_columns_train.append(expanded_data)
    
    #expanded_columns_train.append({f'Dimension_{column_name}': expanded_data})
    
final_dataframe_train = pd.DataFrame({f'Dimension_{i + 1}':col for i, col in enumerate(expanded_columns_train)})

# %%
column_mapping = {f'Dimension_{i}': f'Dimension_{column_name[i]}' for i in range(24)}

final_dataframe_train.rename(columns=column_mapping, inplace=True)
final_dataframe_train
# Out:
#       Dimension_10  Dimension_11  Dimension_12  Dimension_13  Dimension_14  \
# 0         0.599967     -0.823936     -0.286140     -0.507478     -1.369001
# 1         0.597535     -0.822723     -0.285675     -0.489377     -1.382364
# 2         0.597007     -0.820954     -0.285412     -0.510865     -1.371936
# 3         0.599099     -0.822648     -0.285793     -0.506752     -1.383616
# 4         0.606181     -0.826938     -0.290546     -0.529976     -1.560801
# ...            ...           ...           ...           ...           ...
# 9175      0.732601     -0.700097     -0.159149     -0.681281     -1.037294
# 9176      0.667282     -0.723257     -0.200639     -0.567097     -1.201059
# 9177      0.579626     -0.812076     -0.226776     -0.570880     -1.261680
# 9178      0.565539     -0.818442     -0.224170     -0.577529     -1.371884
# 9179      0.566283     -0.821783     -0.219095     -0.630105     -1.351009
#
#       Dimension_15  Dimension_16  Dimension_17  Dimension_18  Dimension_0  \
# 0        -0.515990      0.577993     -1.534954     -0.673190    -0.536343
# 1        -0.537491      0.576627     -1.532795     -0.671919    -0.533816
# 2        -0.510966      0.576456     -1.532478     -0.671555    -0.526319
# 3        -0.530980      0.579362     -1.535441     -0.672198    -0.554538
# 4        -0.658221      0.626759     -1.482552     -0.659393    -0.576196
# ...            ...           ...           ...           ...          ...
# 9175     -0.926273      0.759877     -1.023339     -0.815714    -0.642529
# 9176     -0.897129      0.612297     -1.165635     -0.781722    -0.320298
# 9177     -0.779676      0.453598     -1.538221     -0.713111    -0.238461
# 9178     -0.673963      0.479162     -1.413416     -0.642361    -0.360042
# 9179     -0.628867      0.486920     -1.420530     -0.616038    -0.494218
#
#       ...  Dimension_23  Dimension_1  Dimension_2  Dimension_3  Dimension_4  \
# 0     ...     -1.771773    -0.810086    -1.821679    -0.846321     0.465208
# 1     ...     -1.796660    -0.818863    -1.841987    -0.846325     0.467033
# 2     ...     -1.738568    -0.788060    -1.821358    -0.839571     0.471135
# 3     ...     -1.749744    -0.816695    -1.845643    -0.848031     0.506153
# 4     ...     -1.664565    -0.857897    -1.941721    -0.885500     0.611207
# ...   ...           ...          ...          ...          ...          ...
# 9175  ...     -1.299494    -1.166928    -1.302773    -1.287290     0.630706
# 9176  ...     -1.477854    -1.052576    -1.527531    -1.105582     0.465392
# 9177  ...     -1.619070    -0.744291    -1.604088    -1.019715     0.369039
# 9178  ...     -1.569187    -0.674204    -1.758361    -0.837733     0.353879
# 9179  ...     -1.532149    -0.661219    -1.689460    -0.817575     0.367535
#
#       Dimension_5  Dimension_6  Dimension_7  Dimension_8  Dimension_24
# 0       -2.015072    -0.839242    -0.564097    -0.796225     -0.149604
# 1       -2.007557    -0.838151    -0.564499    -0.797622     -0.150012
# 2       -2.010042    -0.832021    -0.563753    -0.795704     -0.151608
# 3       -2.032552    -0.841696    -0.565008    -0.790238     -0.152350
# 4       -1.953282    -0.902529    -0.573550    -0.799730     -0.169575
# ...           ...          ...          ...          ...           ...
# 9175    -1.272776    -1.254377    -0.884893    -0.657577     -0.291536
# 9176    -1.509743    -1.149427    -0.849941    -0.687176     -0.296518
# 9177    -1.748786    -1.020002    -0.740238    -0.733597     -0.224475
# 9178    -1.854670    -0.783537    -0.700202    -0.745535     -0.216166
# 9179    -1.877205    -0.772260    -0.698746    -0.759947     -0.216923
#
# [9180 rows x 24 columns]

# %%
index_values = []
index_ranges = [(i // 51) + 1 for i in range(9180)]

for index in index_ranges:
    index_values.extend([index])
    
final_dataframe_train.insert(0, 'sample_id', index_values)

final_dataframe_train.insert(1, 'data_type', 0)

# %%
class_values = []

for _, row in final_dataframe_train.iterrows():
    
    sample_id = row['sample_id']
    
    class_value = datasets_train[0].loc[datasets_train[0]['sample_id'] == sample_id, 'classAttribute'].values[0]
    
    class_values.append(class_value)
    
final_dataframe_train['classAttribute'] = class_values

final_dataframe_train
# Out:
#       sample_id  data_type  Dimension_10  Dimension_11  Dimension_12  \
# 0             1          0      0.599967     -0.823936     -0.286140
# 1             1          0      0.597535     -0.822723     -0.285675
# 2             1          0      0.597007     -0.820954     -0.285412
# 3             1          0      0.599099     -0.822648     -0.285793
# 4             1          0      0.606181     -0.826938     -0.290546
# ...         ...        ...           ...           ...           ...
# 9175        180          0      0.732601     -0.700097     -0.159149
# 9176        180          0      0.667282     -0.723257     -0.200639
# 9177        180          0      0.579626     -0.812076     -0.226776
# 9178        180          0      0.565539     -0.818442     -0.224170
# 9179        180          0      0.566283     -0.821783     -0.219095
#
#       Dimension_13  Dimension_14  Dimension_15  Dimension_16  Dimension_17  \
# 0        -0.507478     -1.369001     -0.515990      0.577993     -1.534954
# 1        -0.489377     -1.382364     -0.537491      0.576627     -1.532795
# 2        -0.510865     -1.371936     -0.510966      0.576456     -1.532478
# 3        -0.506752     -1.383616     -0.530980      0.579362     -1.535441
# 4        -0.529976     -1.560801     -0.658221      0.626759     -1.482552
# ...            ...           ...           ...           ...           ...
# 9175     -0.681281     -1.037294     -0.926273      0.759877     -1.023339
# 9176     -0.567097     -1.201059     -0.897129      0.612297     -1.165635
# 9177     -0.570880     -1.261680     -0.779676      0.453598     -1.538221
# 9178     -0.577529     -1.371884     -0.673963      0.479162     -1.413416
# 9179     -0.630105     -1.351009     -0.628867      0.486920     -1.420530
#
#       ...  Dimension_1  Dimension_2  Dimension_3  Dimension_4  Dimension_5  \
# 0     ...    -0.810086    -1.821679    -0.846321     0.465208    -2.015072
# 1     ...    -0.818863    -1.841987    -0.846325     0.467033    -2.007557
# 2     ...    -0.788060    -1.821358    -0.839571     0.471135    -2.010042
# 3     ...    -0.816695    -1.845643    -0.848031     0.506153    -2.032552
# 4     ...    -0.857897    -1.941721    -0.885500     0.611207    -1.953282
# ...   ...          ...          ...          ...          ...          ...
# 9175  ...    -1.166928    -1.302773    -1.287290     0.630706    -1.272776
# 9176  ...    -1.052576    -1.527531    -1.105582     0.465392    -1.509743
# 9177  ...    -0.744291    -1.604088    -1.019715     0.369039    -1.748786
# 9178  ...    -0.674204    -1.758361    -0.837733     0.353879    -1.854670
# 9179  ...    -0.661219    -1.689460    -0.817575     0.367535    -1.877205
#
#       Dimension_6  Dimension_7  Dimension_8  Dimension_24  classAttribute
# 0       -0.839242    -0.564097    -0.796225     -0.149604          b'4.0'
# 1       -0.838151    -0.564499    -0.797622     -0.150012          b'4.0'
# 2       -0.832021    -0.563753    -0.795704     -0.151608          b'4.0'
# 3       -0.841696    -0.565008    -0.790238     -0.152350          b'4.0'
# 4       -0.902529    -0.573550    -0.799730     -0.169575          b'4.0'
# ...           ...          ...          ...           ...             ...
# 9175    -1.254377    -0.884893    -0.657577     -0.291536          b'4.0'
# 9176    -1.149427    -0.849941    -0.687176     -0.296518          b'4.0'
# 9177    -1.020002    -0.740238    -0.733597     -0.224475          b'4.0'
# 9178    -0.783537    -0.700202    -0.745535     -0.216166          b'4.0'
# 9179    -0.772260    -0.698746    -0.759947     -0.216923          b'4.0'
#
# [9180 rows x 27 columns]

# %% [markdown]
# # testing dataset

# %%
datasets_test = []

# %%
# Read and convert each ARFF file to DataFrame
for file_name in file_list_test:
    file_path = os.path.join(fill_dirc, file_name)
    data, meta = arff.loadarff(file_path)

    df = pd.DataFrame(data)

    datasets_test.append(df)
    
for df in datasets_test:
  
    df.insert(0, 'sample_id', range(1, 181))

    # for test data, data_type = 1
    df.insert(1, 'data_type', 1)

# %%
datasets_test[0]
# Out:
#      sample_id  data_type  channel_9_0  channel_9_1  channel_9_2  channel_9_3  \
# 0            1          1     0.631310     0.632066     0.633518     0.634159
# 1            2          1     0.603517     0.603864     0.603447     0.605941
# 2            3          1     0.610460     0.610576     0.611043     0.611731
# 3            4          1     0.623494     0.623521     0.622819     0.623389
# 4            5          1     0.537046     0.534438     0.535729     0.574555
# ..         ...        ...          ...          ...          ...          ...
# 175        176          1     0.568073     0.568343     0.568410     0.568293
# 176        177          1     0.647934     0.640079     0.648869     0.656904
# 177        178          1     0.591388     0.591337     0.591085     0.591853
# 178        179          1     0.657806     0.657696     0.657668     0.657513
# 179        180          1     0.580963     0.581300     0.581023     0.582489
#
#      channel_9_4  channel_9_5  channel_9_6  channel_9_7  ...  channel_9_42  \
# 0       0.634378     0.634201     0.634011     0.633416  ...      0.851869
# 1       0.611514     0.612704     0.613881     0.614897  ...      0.671971
# 2       0.614399     0.621468     0.670891     0.720413  ...      0.411778
# 3       0.623679     0.623099     0.623489     0.623793  ...      1.113182
# 4       0.646644     0.712267     0.813449     0.878566  ...      0.939371
# ..           ...          ...          ...          ...  ...           ...
# 175     0.568819     0.569378     0.579864     0.641647  ...      0.547923
# 176     0.658051     0.658791     0.645045     0.650092  ...      0.723500
# 177     0.592227     0.595712     0.615393     0.661768  ...      0.587594
# 178     0.657218     0.657319     0.657330     0.657389  ...      0.797923
# 179     0.590473     0.619593     0.692154     0.791487  ...      0.914131
#
#      channel_9_43  channel_9_44  channel_9_45  channel_9_46  channel_9_47  \
# 0        0.679789      0.643968      0.645137      0.669241      0.688313
# 1        0.691724      0.693383      0.684894      0.668692      0.657812
# 2        0.411017      0.403645      0.406055      0.408695      0.412244
# 3        1.123276      1.116178      1.100938      1.111847      1.052793
# 4        0.871109      0.792143      0.730648      0.661121      0.593642
# ..            ...           ...           ...           ...           ...
# 175      0.549948      0.552344      0.554555      0.557303      0.559503
# 176      0.647550      0.547676      0.637955      0.618817      0.580544
# 177      0.582562      0.586586      0.590938      0.586935      0.588945
# 178      0.668278      0.622164      0.626416      0.639333      0.644928
# 179      0.829735      0.777838      0.730153      0.673925      0.630602
#
#      channel_9_48  channel_9_49  channel_9_50  classAttribute
# 0        0.692915      0.697734      0.696126          b'4.0'
# 1        0.652036      0.646966      0.643236          b'5.0'
# 2        0.417122      0.419511      0.417039          b'6.0'
# 3        0.994028      0.892853      0.801899          b'1.0'
# 4        0.569707      0.558200      0.553536          b'4.0'
# ..            ...           ...           ...             ...
# 175      0.561010      0.562791      0.564339          b'6.0'
# 176      0.580074      0.581936      0.580918          b'3.0'
# 177      0.589750      0.590849      0.592010          b'5.0'
# 178      0.645005      0.641324      0.634571          b'4.0'
# 179      0.607822      0.600801      0.597154          b'4.0'
#
# [180 rows x 54 columns]

# %%
expanded_columns_test = []
column_name_test = []

for df in datasets_test:
    selected_data = df.iloc[:, 2:53]
    
    column_name_test.append(df.columns[2].split('_')[1])

    expanded_data = []
    
    for _, row in selected_data.iterrows():
        
        expanded_data.extend(row.tolist())
        
    
    expanded_columns_test.append(expanded_data)
    
final_dataframe_test = pd.DataFrame({f'Dimension_{i + 1}':col for i, col in enumerate(expanded_columns_test)})

# %%
column_mapping_test = {f'Dimension_{i}': f'Dimension_{column_name[i]}' for i in range(24)}

final_dataframe_test.rename(columns=column_mapping_test, inplace=True)
final_dataframe_test
# Out:
#       Dimension_10  Dimension_11  Dimension_12  Dimension_13  Dimension_14  \
# 0         0.631310     -0.807240     -0.279330     -0.630195     -1.451361
# 1         0.632066     -0.807258     -0.278007     -0.626388     -1.464355
# 2         0.633518     -0.807240     -0.274849     -0.642930     -1.462434
# 3         0.634159     -0.809020     -0.274106     -0.666163     -1.477584
# 4         0.634378     -0.809834     -0.273313     -0.663127     -1.492872
# ...            ...           ...           ...           ...           ...
# 9175      0.673925     -0.822626      0.058216     -0.879236     -1.428410
# 9176      0.630602     -0.856600      0.034010     -0.814410     -1.487098
# 9177      0.607822     -0.862768      0.019406     -0.782641     -1.469383
# 9178      0.600801     -0.858134      0.009664     -0.766994     -1.464376
# 9179      0.597154     -0.854429      0.003888     -0.759306     -1.456960
#
#       Dimension_15  Dimension_16  Dimension_17  Dimension_18  Dimension_0  \
# 0        -0.465686      0.665998     -1.593898     -0.737468    -0.707356
# 1        -0.474674      0.666855     -1.595835     -0.737365    -0.706467
# 2        -0.474046      0.669992     -1.597528     -0.735672    -0.712429
# 3        -0.476590      0.671575     -1.599879     -0.736326    -0.715938
# 4        -0.505572      0.672169     -1.601423     -0.736355    -0.715920
# ...            ...           ...           ...           ...          ...
# 9175     -0.402750      0.857950     -1.527194     -0.315056    -0.889773
# 9176     -0.426398      0.737224     -1.501386     -0.315699    -0.642052
# 9177     -0.430941      0.659843     -1.503965     -0.324704    -0.609636
# 9178     -0.438325      0.597387     -1.612530     -0.412526    -0.560203
# 9179     -0.445572      0.591917     -1.623406     -0.413167    -0.557817
#
#       ...  Dimension_23  Dimension_1  Dimension_2  Dimension_3  Dimension_4  \
# 0     ...     -1.617470    -0.806243    -1.897467    -0.689874     0.597063
# 1     ...     -1.624086    -0.804118    -1.922840    -0.700692     0.594941
# 2     ...     -1.621753    -0.805056    -1.912729    -0.702529     0.599973
# 3     ...     -1.628024    -0.803497    -1.930459    -0.711766     0.605679
# 4     ...     -1.625307    -0.803804    -1.935742    -0.727374     0.597675
# ...   ...           ...          ...          ...          ...          ...
# 9175  ...     -1.659452    -0.607189    -1.919878    -0.583276     0.856647
# 9176  ...     -1.727294    -0.618963    -1.945017    -0.587023     0.680567
# 9177  ...     -1.877402    -0.412571    -1.933950    -0.615705     0.574144
# 9178  ...     -1.903281    -0.472645    -1.916436    -0.634439     0.478221
# 9179  ...     -1.895895    -0.454302    -1.911442    -0.656298     0.469341
#
#       Dimension_5  Dimension_6  Dimension_7  Dimension_8  Dimension_24
# 0       -1.922938    -0.836496    -0.586639    -0.827417     -0.100443
# 1       -1.922243    -0.834670    -0.587231    -0.831042     -0.103778
# 2       -1.917021    -0.838037    -0.590665    -0.840662     -0.110054
# 3       -1.917102    -0.841104    -0.590144    -0.823007     -0.115432
# 4       -1.918653    -0.842211    -0.594716    -0.835395     -0.121241
# ...           ...          ...          ...          ...           ...
# 9175    -1.978063    -0.553987    -0.790264    -0.770808     -0.075527
# 9176    -1.992559    -0.566642    -0.759338    -0.790078     -0.090382
# 9177    -1.986102    -0.572386    -0.741427    -0.793610     -0.100764
# 9178    -2.078024    -0.620835    -0.731334    -0.790556     -0.109856
# 9179    -2.086228    -0.644960    -0.725837    -0.787746     -0.116215
#
# [9180 rows x 24 columns]

# %%
index_values_test = []
index_ranges_test = [(i // 51) + 1 for i in range(9180)]

for index in index_ranges_test:
    index_values_test.extend([index])
    
final_dataframe_test.insert(0, 'sample_id', index_values_test)

final_dataframe_test.insert(1, 'data_type', 1)

# %%
class_values_test = []

for _, row in final_dataframe_test.iterrows():
    
    sample_id = row['sample_id']
    
    class_value_test = datasets_test[0].loc[datasets_test[0]['sample_id'] == sample_id, 'classAttribute'].values[0]
    
    class_values_test.append(class_value_test)
    
final_dataframe_test['classAttribute'] = class_values_test

final_dataframe_test
# Out:
#       sample_id  data_type  Dimension_10  Dimension_11  Dimension_12  \
# 0             1          1      0.631310     -0.807240     -0.279330
# 1             1          1      0.632066     -0.807258     -0.278007
# 2             1          1      0.633518     -0.807240     -0.274849
# 3             1          1      0.634159     -0.809020     -0.274106
# 4             1          1      0.634378     -0.809834     -0.273313
# ...         ...        ...           ...           ...           ...
# 9175        180          1      0.673925     -0.822626      0.058216
# 9176        180          1      0.630602     -0.856600      0.034010
# 9177        180          1      0.607822     -0.862768      0.019406
# 9178        180          1      0.600801     -0.858134      0.009664
# 9179        180          1      0.597154     -0.854429      0.003888
#
#       Dimension_13  Dimension_14  Dimension_15  Dimension_16  Dimension_17  \
# 0        -0.630195     -1.451361     -0.465686      0.665998     -1.593898
# 1        -0.626388     -1.464355     -0.474674      0.666855     -1.595835
# 2        -0.642930     -1.462434     -0.474046      0.669992     -1.597528
# 3        -0.666163     -1.477584     -0.476590      0.671575     -1.599879
# 4        -0.663127     -1.492872     -0.505572      0.672169     -1.601423
# ...            ...           ...           ...           ...           ...
# 9175     -0.879236     -1.428410     -0.402750      0.857950     -1.527194
# 9176     -0.814410     -1.487098     -0.426398      0.737224     -1.501386
# 9177     -0.782641     -1.469383     -0.430941      0.659843     -1.503965
# 9178     -0.766994     -1.464376     -0.438325      0.597387     -1.612530
# 9179     -0.759306     -1.456960     -0.445572      0.591917     -1.623406
#
#       ...  Dimension_1  Dimension_2  Dimension_3  Dimension_4  Dimension_5  \
# 0     ...    -0.806243    -1.897467    -0.689874     0.597063    -1.922938
# 1     ...    -0.804118    -1.922840    -0.700692     0.594941    -1.922243
# 2     ...    -0.805056    -1.912729    -0.702529     0.599973    -1.917021
# 3     ...    -0.803497    -1.930459    -0.711766     0.605679    -1.917102
# 4     ...    -0.803804    -1.935742    -0.727374     0.597675    -1.918653
# ...   ...          ...          ...          ...          ...          ...
# 9175  ...    -0.607189    -1.919878    -0.583276     0.856647    -1.978063
# 9176  ...    -0.618963    -1.945017    -0.587023     0.680567    -1.992559
# 9177  ...    -0.412571    -1.933950    -0.615705     0.574144    -1.986102
# 9178  ...    -0.472645    -1.916436    -0.634439     0.478221    -2.078024
# 9179  ...    -0.454302    -1.911442    -0.656298     0.469341    -2.086228
#
#       Dimension_6  Dimension_7  Dimension_8  Dimension_24  classAttribute
# 0       -0.836496    -0.586639    -0.827417     -0.100443          b'4.0'
# 1       -0.834670    -0.587231    -0.831042     -0.103778          b'4.0'
# 2       -0.838037    -0.590665    -0.840662     -0.110054          b'4.0'
# 3       -0.841104    -0.590144    -0.823007     -0.115432          b'4.0'
# 4       -0.842211    -0.594716    -0.835395     -0.121241          b'4.0'
# ...           ...          ...          ...           ...             ...
# 9175    -0.553987    -0.790264    -0.770808     -0.075527          b'4.0'
# 9176    -0.566642    -0.759338    -0.790078     -0.090382          b'4.0'
# 9177    -0.572386    -0.741427    -0.793610     -0.100764          b'4.0'
# 9178    -0.620835    -0.731334    -0.790556     -0.109856          b'4.0'
# 9179    -0.644960    -0.725837    -0.787746     -0.116215          b'4.0'
#
# [9180 rows x 27 columns]

# %% [markdown]
# # combine train dataset and test dataset

# %%
final_combined_dataframe = pd.concat([final_dataframe_test, final_dataframe_train], axis=0)
final_combined_dataframe
# Out:
#       sample_id  data_type  Dimension_10  Dimension_11  Dimension_12  \
# 0             1          1      0.631310     -0.807240     -0.279330
# 1             1          1      0.632066     -0.807258     -0.278007
# 2             1          1      0.633518     -0.807240     -0.274849
# 3             1          1      0.634159     -0.809020     -0.274106
# 4             1          1      0.634378     -0.809834     -0.273313
# ...         ...        ...           ...           ...           ...
# 9175        180          0      0.732601     -0.700097     -0.159149
# 9176        180          0      0.667282     -0.723257     -0.200639
# 9177        180          0      0.579626     -0.812076     -0.226776
# 9178        180          0      0.565539     -0.818442     -0.224170
# 9179        180          0      0.566283     -0.821783     -0.219095
#
#       Dimension_13  Dimension_14  Dimension_15  Dimension_16  Dimension_17  \
# 0        -0.630195     -1.451361     -0.465686      0.665998     -1.593898
# 1        -0.626388     -1.464355     -0.474674      0.666855     -1.595835
# 2        -0.642930     -1.462434     -0.474046      0.669992     -1.597528
# 3        -0.666163     -1.477584     -0.476590      0.671575     -1.599879
# 4        -0.663127     -1.492872     -0.505572      0.672169     -1.601423
# ...            ...           ...           ...           ...           ...
# 9175     -0.681281     -1.037294     -0.926273      0.759877     -1.023339
# 9176     -0.567097     -1.201059     -0.897129      0.612297     -1.165635
# 9177     -0.570880     -1.261680     -0.779676      0.453598     -1.538221
# 9178     -0.577529     -1.371884     -0.673963      0.479162     -1.413416
# 9179     -0.630105     -1.351009     -0.628867      0.486920     -1.420530
#
#       ...  Dimension_1  Dimension_2  Dimension_3  Dimension_4  Dimension_5  \
# 0     ...    -0.806243    -1.897467    -0.689874     0.597063    -1.922938
# 1     ...    -0.804118    -1.922840    -0.700692     0.594941    -1.922243
# 2     ...    -0.805056    -1.912729    -0.702529     0.599973    -1.917021
# 3     ...    -0.803497    -1.930459    -0.711766     0.605679    -1.917102
# 4     ...    -0.803804    -1.935742    -0.727374     0.597675    -1.918653
# ...   ...          ...          ...          ...          ...          ...
# 9175  ...    -1.166928    -1.302773    -1.287290     0.630706    -1.272776
# 9176  ...    -1.052576    -1.527531    -1.105582     0.465392    -1.509743
# 9177  ...    -0.744291    -1.604088    -1.019715     0.369039    -1.748786
# 9178  ...    -0.674204    -1.758361    -0.837733     0.353879    -1.854670
# 9179  ...    -0.661219    -1.689460    -0.817575     0.367535    -1.877205
#
#       Dimension_6  Dimension_7  Dimension_8  Dimension_24  classAttribute
# 0       -0.836496    -0.586639    -0.827417     -0.100443          b'4.0'
# 1       -0.834670    -0.587231    -0.831042     -0.103778          b'4.0'
# 2       -0.838037    -0.590665    -0.840662     -0.110054          b'4.0'
# 3       -0.841104    -0.590144    -0.823007     -0.115432          b'4.0'
# 4       -0.842211    -0.594716    -0.835395     -0.121241          b'4.0'
# ...           ...          ...          ...           ...             ...
# 9175    -1.254377    -0.884893    -0.657577     -0.291536          b'4.0'
# 9176    -1.149427    -0.849941    -0.687176     -0.296518          b'4.0'
# 9177    -1.020002    -0.740238    -0.733597     -0.224475          b'4.0'
# 9178    -0.783537    -0.700202    -0.745535     -0.216166          b'4.0'
# 9179    -0.772260    -0.698746    -0.759947     -0.216923          b'4.0'
#
# [18360 rows x 27 columns]

# %%
final_combined_dataframe.head()
# Out:
#    sample_id  data_type  Dimension_10  Dimension_11  Dimension_12  \
# 0          1          1      0.631310     -0.807240     -0.279330
# 1          1          1      0.632066     -0.807258     -0.278007
# 2          1          1      0.633518     -0.807240     -0.274849
# 3          1          1      0.634159     -0.809020     -0.274106
# 4          1          1      0.634378     -0.809834     -0.273313
#
#    Dimension_13  Dimension_14  Dimension_15  Dimension_16  Dimension_17  ...  \
# 0     -0.630195     -1.451361     -0.465686      0.665998     -1.593898  ...
# 1     -0.626388     -1.464355     -0.474674      0.666855     -1.595835  ...
# 2     -0.642930     -1.462434     -0.474046      0.669992     -1.597528  ...
# 3     -0.666163     -1.477584     -0.476590      0.671575     -1.599879  ...
# 4     -0.663127     -1.492872     -0.505572      0.672169     -1.601423  ...
#
#    Dimension_1  Dimension_2  Dimension_3  Dimension_4  Dimension_5  \
# 0    -0.806243    -1.897467    -0.689874     0.597063    -1.922938
# 1    -0.804118    -1.922840    -0.700692     0.594941    -1.922243
# 2    -0.805056    -1.912729    -0.702529     0.599973    -1.917021
# 3    -0.803497    -1.930459    -0.711766     0.605679    -1.917102
# 4    -0.803804    -1.935742    -0.727374     0.597675    -1.918653
#
#    Dimension_6  Dimension_7  Dimension_8  Dimension_24  classAttribute
# 0    -0.836496    -0.586639    -0.827417     -0.100443          b'4.0'
# 1    -0.834670    -0.587231    -0.831042     -0.103778          b'4.0'
# 2    -0.838037    -0.590665    -0.840662     -0.110054          b'4.0'
# 3    -0.841104    -0.590144    -0.823007     -0.115432          b'4.0'
# 4    -0.842211    -0.594716    -0.835395     -0.121241          b'4.0'
#
# [5 rows x 27 columns]

# %%
final_combined_dataframe.to_csv('final_combined_data.csv', index=False)
