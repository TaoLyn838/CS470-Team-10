# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
file_path = 'NATOPS_sid20-C_TRAIN_su.csv'  
natops_data = pd.read_csv(file_path)

# %%
natops_data
# Out:
#        isTest      fea2      fea3  fea4      fea5      fea6      fea7  \
# 0           0  0.117647  0.039216   0.0  0.137255  0.019608  0.098039
# 1           0  0.117647  0.039216   0.0  0.137255  0.019608  0.098039
# 2           0  0.117647  0.039216   0.0  0.137255  0.019608  0.098039
# 3           0  0.117647  0.039216   0.0  0.137255  0.019608  0.098039
# 4           0  0.117647  0.039216   0.0  0.137255  0.019608  0.098039
# ...       ...       ...       ...   ...       ...       ...       ...
# 18355       1  0.215686  0.000000   0.0  0.196078  0.078431  0.156863
# 18356       1  0.215686  0.000000   0.0  0.196078  0.078431  0.156863
# 18357       1  0.215686  0.000000   0.0  0.196078  0.078431  0.156863
# 18358       1  0.215686  0.000000   0.0  0.196078  0.078431  0.156863
# 18359       1  0.215686  0.000000   0.0  0.196078  0.078431  0.156863
#
#            fea8  fea9  fea10  ...  fea14  fea15     fea16     fea17     fea18  \
# ...

# %%
data_processed = natops_data.drop(['isTest'], axis=1)

# %%
data_processed = data_processed.drop(['sid'], axis=1)

# %%
data_processed.to_csv("data_processed.csv", index=False)

# %%
features = data_processed.drop(['class'], axis=1)

# %%
target = data_processed['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(feature, target, test_size=0.3)

# %%
X_train
# Out:
#            fea2      fea3      fea4      fea5      fea6      fea7      fea8  \
# 4152   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.352941
# 9097   0.058824  0.000000  0.294118  0.137255  0.000000  0.078431  0.000000
# 5232   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9764   0.117647  0.000000  0.196078  0.117647  0.000000  0.019608  0.000000
# 12923  0.098039  0.039216  0.000000  0.274510  0.000000  0.058824  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 7604   0.039216  0.117647  0.000000  0.078431  0.019608  0.137255  0.000000
# 4480   0.058824  0.058824  0.000000  0.078431  0.176471  0.039216  0.000000
# 13094  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10952  0.215686  0.000000  0.000000  0.098039  0.176471  0.117647  0.000000
# 15260  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
Z_score_normalization = StandardScaler()
X_train_scaled = Z_score_normalization.fit_transform(X_train)
X_test_scaled = Z_score_normalization.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[-0.59998529, -0.49970823, -0.39463257, ..., -0.27895155,
#         -0.32914133, -0.42078818],
#        [ 0.11147197, -0.26160902, -0.39463257, ..., -0.27895155,
#         -0.32914133, -0.42078818],
#        [-0.59998529, -0.49970823, -0.39463257, ..., -0.27895155,
#         -0.32914133, -0.42078818],
#        ...,
#        [-0.59998529, -0.49970823, -0.39463257, ..., -0.27895155,
#         -0.32914133, -0.42078818],
#        [-0.59998529, -0.49970823, -0.39463257, ..., -0.27895155,
#         -0.32914133, -0.42078818],
#        [-0.59998529, -0.49970823, -0.39463257, ..., -0.27895155,
#         -0.32914133, -0.42078818]])
